# %% [markdown]
# # Uppgift 0 - Uppvärmning

# %%
import pandas as pd

# importing data to create a dataframe
df_events = pd.read_csv("../Data/athlete_events.csv")

df_regions = pd.read_csv("../Data/noc_regions.csv")

# %%
df_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_events.isnull().sum().sum() # there is 363853 NaN values in this dataframe
# Out:
# 363853

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df_regions.isnull().sum().sum() # there is 212 NaN values in this dataframe
# Out:
# 212

# %% [markdown]
# ----
# #### a. hur många länder som är med i datan?

# %%
countries = df_regions["region"].count()
NaN_countries = df_regions["region"].isnull().sum() # counting the Nan values 
country_count = countries - NaN_countries
print(f"There are {country_count} different Countries in this dataset")

# have to question this as there are for examples of individual olympic athletes and refugee athletes tex
# Out:
# There are 224 different Countries in this dataset

# %% [markdown]
# ----
# #### b. vilka länder är med? (förkortningarna räcker)

# %%
countries_list = df_regions["region"].squeeze().dropna()
countries_list.tolist()
# Out:
# ['Afghanistan',
#  'Curacao',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua',
#  'Australia',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'American Samoa',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bangladesh',
#  'Barbados',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bosnia and Herzegovina',
#  'Belize',
#  'Belarus',
#  'Czech Republic',
#  'Boliva',
#  'Botswana',
#  'Brazil',
#  'Bahrain',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Central African Republic',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Republic of Congo',
#  'Chad',
#  'Chile',
#  'China',
#  'Ivory Coast',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cape Verde',
#  'Costa Rica',
#  'Croatia',
#  'Greece',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
# ...

# %% [markdown]
# ----
# #### c. vilka sporter är med?

# %%
df_sport_types = df_events[["Sport"]].groupby("Sport").sum(True)
df_sport_types
# How to visualize this so i can see the whole
# Out:
# Empty DataFrame
# Columns: []
# Index: [Aeronautics, Alpine Skiing, Alpinism, Archery, Art Competitions, Athletics, Badminton, Baseball, Basketball, Basque Pelota, Beach Volleyball, Biathlon, Bobsleigh, Boxing, Canoeing, Cricket, Croquet, Cross Country Skiing, Curling, Cycling, Diving, Equestrianism, Fencing, Figure Skating, Football, Freestyle Skiing, Golf, Gymnastics, Handball, Hockey, Ice Hockey, Jeu De Paume, Judo, Lacrosse, Luge, Military Ski Patrol, Modern Pentathlon, Motorboating, Nordic Combined, Polo, Racquets, Rhythmic Gymnastics, Roque, Rowing, Rugby, Rugby Sevens, Sailing, Shooting, Short Track Speed Skating, Skeleton, Ski Jumping, Snowboarding, Softball, Speed Skating, Swimming, Synchronized Swimming, Table Tennis, Taekwondo, Tennis, Trampolining, Triathlon, Tug-Of-War, Volleyball, Water Polo, Weightlifting, Wrestling]
#
# [66 rows x 0 columns]

# %%
df_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ----
# ####   d. vilka medaljtyper finns det?

# %%
df_medals = df_events[["Medal"]].groupby("Medal").sum(True)
df_medals
# Out:
# Empty DataFrame
# Columns: []
# Index: [Bronze, Gold, Silver]

# %% [markdown]
# ----
# #### e. ta reda på statistik för åldern: medelvärde, median, min, max, standardavvikelse,

# %%
df_age = df_events[["Age"]].dropna(inplace=False).sort_values(by=["Age"])

median = df_age.median()
mean = df_age.mean()
mode = df_age.mode().squeeze()
min_age = df_age.iloc[[0]].squeeze() # Squeeze converts dataframe to a series
max_age = df_age.iloc[[-1]].squeeze()
print(f"The median age is {median.to_string()}")
print(f"The mean age is {mean.to_string()}")
print(f"The mode age is {mode}")
print(f"The minimum age is {min_age}")
print(f"The max age is {max_age}")
# Out:
# The median age is Age    24.0
# The mean age is Age    25.556898
# The mode age is 23.0
# The minimum age is 10.0
# The max age is 97.0

# %% [markdown]
# ----
# #### f. utforska datan vidare med egna frågor

# %%
df_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Which teams have the most medals

df_medal_count = df_events.groupby(["NOC","Medal"]).Medal.count().reset_index(name='counts')

df_medal_count = df_medal_count.sort_values("NOC")

#df_medal_count = df_medal_count["Team"].Team.count()

#df_medal_count = df_medal_count

#df_medal_count = df_medal_count.groupby(["Team"],sort=True).sum()
#df_medal_count["Gold"] = df_medal_count["Medal"].value_counts().Gold
#df_medal_count["Silver"] = df_medal_count["Medal"].value_counts().Silver
#df_medal_count["Bronze"] = df_medal_count["Medal"].value_counts().Bronze
df_medal_count
# Out:
#      NOC   Medal  counts
# 0    AFG  Bronze       2
# 1    AHO  Silver       1
# 2    ALG  Bronze       8
# 3    ALG    Gold       5
# 4    ALG  Silver       4
# ..   ...     ...     ...
# 357  ZAM  Bronze       1
# 358  ZAM  Silver       1
# 360  ZIM    Gold      17
# 359  ZIM  Bronze       1
# 361  ZIM  Silver       4
#
# [362 rows x 3 columns]

# %%
df_events.head()
df_medals=df_events.loc[df_events["Medal"].notna(),["NOC","Medal"]]


df_medals
# Out:
#         NOC   Medal
# 3       DEN    Gold
# 37      FIN  Bronze
# 38      FIN  Bronze
# 40      FIN  Bronze
# 41      FIN  Bronze
# ...     ...     ...
# 271078  URS  Silver
# 271080  URS  Bronze
# 271082  POL  Bronze
# 271102  RUS  Bronze
# 271103  RUS  Silver
#
# [39783 rows x 2 columns]

# %%
df_medals = df_medals.groupby(["Medal","NOC"]).value_counts().reset_index(name="Total")
df_medals
# Out:
#         Total
# Medal
# Bronze  13295
# Gold    13372
# Silver  13116

# %% [markdown]
# ----
# ## Se även till att plotta några intressanta features, exempelvis:

# %% [markdown]
# ----
# #### g. diagram över könsfördelningen

# %%
# maybe do a pie chart here! 
df_total_gender = df_events[["Sex"]]
df_total_gender[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sam Glass ITHS\.virtualenvs\Databehandling_project_OS-ZMxZ2AEA\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Sam Glass ITHS\.virtualenvs\Databehandling_project_OS-ZMxZ2AEA\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Sam Glass ITHS\.virtualenvs\Databehandling_project_OS-ZMxZ2AEA\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %% [markdown]
# ----
# #### h. diagram över topp 10 länder som tagit flest medaljer

# %% [markdown]
# ----
# #### i. plotta gärna fler saker som är intressant.
